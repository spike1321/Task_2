# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm

# %%
response = requests.get('https://lifehacker.ru/topics/technology/')#https://lifehacker.ru/topics/technology/
response.text
# Out:
# '<!DOCTYPE html><html  lang="ru-RU" data-capo=""><head><meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<title>Технологии — Лайфхакер</title>\n<link rel="preconnect" href="https://www.googletagmanager.com">\n<link rel="preconnect" href="https://top-fwz1.mail.ru">\n<link rel="preconnect" href="https://mc.yandex.ru">\n<link rel="preconnect" href="https://static.criteo.net">\n<link rel="preconnect" href="https://exchange.buzzoola.com">\n<link rel="preconnect" href="https://pb.adriver.ru">\n<link rel="preconnect" href="https://ad.mail.ru">\n<script>window.yaContextCb = window.yaContextCb || [];\nwindow.Ya || (window.Ya = {});\nwindow.Ya.adfoxCode || (window.Ya.adfoxCode = {});\nwindow.Ya.adfoxCode.hbCallbacks || (window.Ya.adfoxCode.hbCallbacks = []);</script>\n<script src="https://yandex.ru/ads/system/context.js" crossorigin="anonymous" async></script>\n<script src="https://yandex.ru/ads/system/header-bidding.js" async></script>\n<style>@font-face{ascent-override:92%;descent-override:14%;font-family:Commissioner Fallback;size-adjust:102%;src:local("Trebuchet MS")}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-ext.DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic.CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-ext.DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin.BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-ext.DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic.CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-ext.DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin.BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{ascent-override:90%;descent-override:20%;font-family:PT Root Fallback;size-adjust:99%;src:local("Arial")}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-ext.DvRWtDjP.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic.BLhMUhD6.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:PT Root; ...

# %%
base_url = 'https://lifehacker.ru/topics/technology/'
response = requests.get('https://lifehacker.ru/topics/technology/') # получаем контент первой страницы
soup = BeautifulSoup(response.text, 'lxml') # инициализируем объект bs4 и задаем парсер lxml

# %%
soup.find_all('a', class_='lh-small-article-card__link') #ищем все a-элементы с классом lh-small-article-card__link
# Out:
# [<a aria-label="Как выбрать саундбар для телевизора, компьютера и смартфона" class="lh-small-article-card__link" data-jest="link" href="/kak-vybrat-saundbar/" title="Как выбрать саундбар для телевизора, компьютера и смартфона"><!--[--><!--]--></a>,
#  <a aria-label="iOS 26 получит «стеклянный дизайн» — Bloomberg раскрыл главные детали грядущего обновления" class="lh-small-article-card__link" data-jest="link" href="/raskryt-dizain-ios-26/" title="iOS 26 получит «стеклянный дизайн» — Bloomberg раскрыл главные детали грядущего обновления"><!--[--><!--]--></a>,
#  <a aria-label="10 бесплатных Android-приложений для изучения английского" class="lh-small-article-card__link" data-jest="link" href="/10-android-apps-to-learn-english/" title="10 бесплатных Android-приложений для изучения английского"><!--[--><!--]--></a>,
#  <a aria-label="Xiaomi выпустила бюджетный планшет Redmi Pad 2 с батареей на 9 000 мА⋅ч" class="lh-small-article-card__link" data-jest="link" href="/anons-redmi-pad-2/" title="Xiaomi выпустила бюджетный планшет Redmi Pad 2 с батареей на 9 000 мА⋅ч"><!--[--><!--]--></a>,
#  <a aria-label="На часах Samsung Galaxy Watch появилось автономное приложение «Яндекс Музыки»" class="lh-small-article-card__link" data-jest="link" href="/yandeks-muzyka-dlya-chasov/" title="На часах Samsung Galaxy Watch появилось автономное приложение «Яндекс Музыки»"><!--[--><!--]--></a>,
#  <a aria-label="Представлен Fi Series 3 Plus — собачий ИИ-ошейник с трекингом здоровья и привычек через Apple&amp;nbsp;Watch" class="lh-small-article-card__link" data-jest="link" href="/anons-fi-series-3-plus/" title="Представлен Fi Series 3 Plus — собачий ИИ-ошейник с трекингом здоровья и привычек через Apple&amp;nbsp;Watch"><!--[--><!--]--></a>,
#  <a aria-label="Как выбрать кондиционер для дома в 2025 году: всё, что нужно знать до покупки" class="lh-small-article-card__link" data-jest="link" href="/kak-vybrat-kondicioner/" title="Как выбрать кондиционер для дома в 2025 году: всё, что нужно знать до покупки"><!--[--><!--]--></a>,
#  <a aria-label="На маркетплейсах начали продавать Nintendo Switch 2 — по цене от 52 тысяч рублей" class="lh-small-article-card__link" data-jest="link" href="/na-marketpleisax-nachali-prodavat-nintendo-switch-2/" title="На маркетплейсах начали продавать Nintendo Switch 2 — по цене от 52 тысяч рублей"><!--[--><!--]--></a>]

# %%
from types import CellType
raw_items = soup.find_all('a', class_='lh-article-card-controls__comments')  # ищем все a-элементы с классом lh-article-card-controls__comments
links = [item.get('href').replace('/#comments', '') for item in raw_items] # получаем у ссылок только href-атрибут, убираем подстроку '/comments'
links
# Out:
# ['/kak-vybrat-saundbar',
#  '/raskryt-dizain-ios-26',
#  '/10-android-apps-to-learn-english',
#  '/anons-redmi-pad-2',
#  '/xiaomi-smart-band-10-utechka',
#  '/prochnost-nintendo-switch-2',
#  '/apple-watch-netochnost',
#  '/kakoi-ryukzak-dlya-noutbuka-kupit',
#  '/anons-shimano-qauto',
#  '/anons-oneplus-pad-3',
#  '/chatgpt-po-foto-kak-ispolzovat',
#  '/novyi-remen-bezopasnosti-volvo',
#  '/imena-polzovatelei-v-whatsapp',
#  '/airpods-kamera-i-son',
#  '/kak-ubrat-carapiny-s-ekrana-vazelinom',
#  '/anons-oneplus-13s',
#  '/rossiiskie-os-vmesto-windows',
#  '/chatgpt-nauchilsya-chitat-faily-iz-google-diska',
#  '/udalenie-akkaunta-samsung',
#  '/utechka-xiaomi-smart-band-10',
#  '/novye-funkcii-v-ios-26',
#  '/5-period-tracking-apps',
#  '/proverit-serijnyj-nomer-iphone',
#  '/apple-design-awards-2025',
#  '/vkladki-v-telegram',
#  '/yandeks-muzyka-dlya-chasov',
#  '/anons-fi-series-3-plus',
#  '/kak-vybrat-kondicioner',
#  '/na-marketpleisax-nachali-prodavat-nintendo-switch-2']

# %%
import requests
requests.get('https://lifehacker.ru/topics/technology/').text
# Out:
# '<!DOCTYPE html><html  lang="ru-RU" data-capo=""><head><meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<title>Технологии — Лайфхакер</title>\n<link rel="preconnect" href="https://www.googletagmanager.com">\n<link rel="preconnect" href="https://top-fwz1.mail.ru">\n<link rel="preconnect" href="https://mc.yandex.ru">\n<link rel="preconnect" href="https://static.criteo.net">\n<link rel="preconnect" href="https://exchange.buzzoola.com">\n<link rel="preconnect" href="https://pb.adriver.ru">\n<link rel="preconnect" href="https://ad.mail.ru">\n<script>window.yaContextCb = window.yaContextCb || [];\nwindow.Ya || (window.Ya = {});\nwindow.Ya.adfoxCode || (window.Ya.adfoxCode = {});\nwindow.Ya.adfoxCode.hbCallbacks || (window.Ya.adfoxCode.hbCallbacks = []);</script>\n<script src="https://yandex.ru/ads/system/context.js" crossorigin="anonymous" async></script>\n<script src="https://yandex.ru/ads/system/header-bidding.js" async></script>\n<style>@font-face{ascent-override:92%;descent-override:14%;font-family:Commissioner Fallback;size-adjust:102%;src:local("Trebuchet MS")}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-ext.DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic.CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-ext.DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin.BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-ext.DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic.CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-ext.DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin.BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{ascent-override:90%;descent-override:20%;font-family:PT Root Fallback;size-adjust:99%;src:local("Arial")}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-ext.DvRWtDjP.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic.BLhMUhD6.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:PT Root; ...

# %%
parsed_urls = []

# %%
for page_num in range(1, 11):
    url = f'{base_url}/?page={page_num}' # подставляем нужный номер страницы для пагинации, дальше парсим каждую страницу аналогично коду выше
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'lxml')
    raw_items = soup.find_all('a', class_='lh-article-card-controls__comments')
    parsed_urls += [item.get('href').replace('/#comments', '') for item in raw_items]

# %%
len(parsed_urls)
# Out:
# 290

# %%
parsed_urls[35:45]
# Out:
# ['/apple-watch-netochnost',
#  '/kakoi-ryukzak-dlya-noutbuka-kupit',
#  '/anons-shimano-qauto',
#  '/anons-oneplus-pad-3',
#  '/chatgpt-po-foto-kak-ispolzovat',
#  '/novyi-remen-bezopasnosti-volvo',
#  '/imena-polzovatelei-v-whatsapp',
#  '/airpods-kamera-i-son',
#  '/kak-ubrat-carapiny-s-ekrana-vazelinom',
#  '/anons-oneplus-13s']

# %%
base_url = 'https://lifehacker.ru/'

# %%
response = requests.get('https://lifehacker.ru/kak-vybrat-saundbar/')
soup = BeautifulSoup(response.text, 'lxml')
soup.find('article', class_='single-article__post-content single-article__content-container').text
# Out:
# 'Саундбар — это компактная аудиосистема в едином корпусе. От обычных портативных колонок он отличается своей конструкцией и технологиями: имеет вытянутую форму и обеспечивает стереофоническое и даже объёмное звучание, несмотря на скромные размеры.Вариантов таких устройств много, и цены отличаются на порядок. Но смысл переплачивать есть далеко не всегда. Всё зависит от того, как и с чем вы планируете использовать саундбар. Вот несколько важных советов по выбору.\xa0Изучите возможности саундбараСаундбары сильно различаются по возможностям: одни будет едва слышно в 2–3 метрах, другие — могут «накрыть» звуком просторный зал. Вот на какие параметры обратить внимание.\xa0Номинальная мощность комплектаТут всё логично —\xa0чем выше мощность, тем громче\xa0звук:До 100 Вт — такие саундбары обеспечивают громкость, достаточную для небольших комнат, таких как спальни или кабинеты. Они подойдут для улучшения звука телевизора, компьютера или смартфона. Но не стоит ожидать мощных басов или объёмного звучания.\n100–300 Вт — саундбары в этом диапазоне мощности подходят для средних помещений, таких как гостиные. Они обеспечивают хороший баланс между громкостью и качеством звука, включая более выраженные басы и чёткость.\xa0\n300–400 Вт — эти устройства обеспечивают мощное и качественное звучание, подходящее для больших помещений или для любителей насыщенного и громкого звука. В них можно ожидать хорошие басы и объём, а также поддержку современных звуковых технологий, таких как Dolby Atmos. Они хорошо подходят для домашнего кинотеатра.\nОт 400 Вт — это премиальные устройства, которые могут заполнить большие помещения громким и детализированным звуком с мощными басами. Часто такие модели оснащены продвинутыми технологиями и дополнительными сабвуферами.\xa0\nЕсли саундбар укомплектован сабвуфером, то имейте в виду, что мощность сабвуфера должна быть примерно вдвое выше мощности самого саундбара. Только в этом случае при увеличении громкости не будет «провала» по нижним частотам.Устройства c разной мощностью:Саундбар Xiaomi Redmi Computer Speaker, 10 Вт от 4 022 рублей\xa0→\nСаундбар Xiaomi MI TV Soundbar 2.0, 84 Вт, от 7 250 рублей\xa0→\nСаундбар Hisense HS2100, 240 Вт, от 9 786 рублей\xa0→\nСаундбар Sony HT-S20R, 400 Вт, от 27 576 рублей\xa0→\nСаундбар Samsung HW-Q990F/RU 2025, 756 Вт, от 117 127 рублей\xa0→\nЗвуковая схемаЗвуковая схема саундбаров обозначается так же, как у других аудиосистем: X.Y.Z. Где, Х — количество каналов, а Y может иметь два значения — 0 и 1, они говорят о наличии сабвуфера. Z в обозначении звуковой схемы встречается нечасто и определяет количество потолочных каналов, ответственных за создание объёмного звука в форматах Dolby Atmos и DTS:X. Изображение: LGКаждый из компонентов схемы оказывает своё влияние на звуковую картину. Схемы могут быть следующими:2.0 — схема большинства бюджетных моделей, фактически представляющих собой пару небольших динамиков в одном корпусе. Качество звука соответствующее.\n2.1 — аналог стереосистемы с сабвуфером. Некоторые многополосные саундбары такой схемы уже могут обеспечить довольно качественный звук.\n3.1 — тот же саундбар с сабвуфером, но к двум боковым каналам добавляется ещё один — в центре. Это позволяет качественнее проигрывать звуковые дорожки фильмов формата Dolby Surround. Боковые каналы отвечают за воспроизведение окружающих звуков, а центральный — за диалоги героев.\n3.1.2 — применительно к саундбарам такая схема означает, что в корпусе установлены дополнительные динамики, направленные вверх. Отражение звуковых волн от потолка создаёт объёмный эффект.\n5.0 — саундбар с пятью раздельными каналами, которые могут быть объединены в одном корпусе. Хотя некоторые модели такой схемы имеют пару отдельных колонок, отвечающих за тыловые каналы.\xa0\n5.1 и 5.1.2 — мощные модели с сабвуфером. Оптимальный вариант для домашнего кинотеатра. Тыловые каналы могут реализовываться отдельными динамиками, а могут быть виртуальными, создаваемыми с помощью отражений звука от стен и потолка — в этом слу ...

# %%
soup.find('h1', class_='article-card__title').text
# Out:
# 'Как выбрать саундбар для телевизора, компьютера и смартфона'

# %%
result = []

for url in tqdm(parsed_urls):
    article = {}

    article_url = f'{base_url}{url}' # подставляем часть ссылки, ведущую материал
    response = requests.get(article_url)
    soup = BeautifulSoup(response.text, 'lxml')

    article['title'] = soup.find('h1', class_='article-card__title').text # Получаем текст из span в первом h1 с классом tm-title_h1
    article['text'] = soup.find('article', class_='single-article__post-content single-article__content-container').text # Получаем весь текст из div с классом tm-article-body
    votes_element = soup.find('span', class_='reactioncurrent-count')
    article['votes_count'] = votes_element.text.strip() if votes_element else 0


    result.append(article)
# Out:
# 100%|██████████| 290/290 [12:08<00:00,  2.51s/it]

# %%
pd.set_option('display.max_colwidth', 400)

# %%
data = pd.DataFrame(result)
data.head()
# Out:
#                                                                                         title  \
# 0                                 Как выбрать саундбар для телевизора, компьютера и смартфона
# 1  iOS 26 получит «стеклянный дизайн» — Bloomberg раскрыл главные детали грядущего обновления
# 2                                   10 бесплатных Android-приложений для изучения английского
# 3                     Xiaomi выпустила бюджетный планшет Redmi Pad 2 с батареей на 9 000 мА⋅ч
# 4    Xiaomi Smart Band 10 показали на официальных изображениях — характеристики подтвердились
#
#                                                                                                                                                                                                                                                                                                                                                                                                               text  \
# 0  Саундбар — это компактная аудиосистема в едином корпусе. От обычных портативных колонок он отличается своей конструкцией и технологиями: имеет вытянутую форму и обеспечивает стереофоническое и даже объёмное звучание, несмотря на скромные размеры.Вариантов таких устройств много, и цены отличаются на порядок. Но смысл переплачивать есть далеко не всегда. Всё зависит от того, как и с чем вы плани...
# 1  В преддверии конференции WWDC25 издание Bloomberg рассказало, какой будет iOS 26. Мобильная система получит масштабный редизайн, который станет самым значительным обновлением платформы со времён iOS 7, выпущенной в 2013 году.Ключевым элементом интерфейса станет концепция «цифрового стекла», делающая акцент на широкое использование света и прозрачности. Панели инструментов, вкладки и иконки при...
# 2  Когда речь заходит об изучении английского с телефона, большинство сразу вспоминают Duolingo — угрожающую зелёную сову знают даже те, кто никогда не учил язык. Но мир образовательных приложений гораздо шире, и среди бесплатных альтернатив можно найти немало достойных решений с разным подходом: от общения с ботами до видеоуроков и геймификации.В этой подборке — приложения, которые помогут улучш...
# 3  Xiaomi представила планшет Redmi Pad 2, который стал преемником модели 2022 года. Изменения минимальны, но заметны: новинка получила более современный и чёткий дисплей, а также увеличенную ёмкость батареи.Девайс оснащён 11-дюймовым ЖК-дисплеем с разрешением 2560 x 1600 пикселей, частотой обновления 90 Гц и максимальной яркостью 600 нит. Теперь он поддерживает работу со стилусом, что расширяет ...
# 4  Портал YTECHB опубликовал рекламные материалы и ключевые характеристики грядущего фитнес-трекера Xiaomi Smart Band 10. Как и предполагалось, основным изменением по сравнению с предыдущей моделью стал увеличенный экран — диагональ выросла на 0,1 дюйма. Браслет оснастят 1,72-дюймовым AMOLED-дисплеем с частотой 60 Гц, яркостью до 1 500 нит и плотностью 326 ppi.Корпус устройства выполнен из алюмин...
#
#    votes_count
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
